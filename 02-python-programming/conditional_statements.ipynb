# %% [markdown]
# Calculator Program

# %%
num1 = float(input("enter your first number"))
operation = input("enter the operation (+, -, *, /): ")
num2 = float(input("enter your second number"))


if operation == '+':
    print("sum:", num1+num2)
elif operation == '-':
    print("substraction: ", num1 - num2)
elif operation == '*':
    print("multiplication: ", num1*num2)
elif operation == '/':
    print("division: ", num1/num2)

# %% [markdown]
# Determine ticket price based on age and whether the person is a student

# %%
age = int(input("enter the person's age"))
is_student = input("are you a student? (YES OR NO)").lower()

if age<5:
    price = "free"
elif age<15:
    price = "$10"
elif age>19:
    if is_student == "yes":
        price = "$18"
    else:
        price = "$25"
print(f"the {age} age's student have to pay {price}")
# Out:
# the 16 age's student have to pay $10
